# %% [markdown]
# # 11. 데이터 정렬

# %%
import pandas as pd
df = pd.read_excel('score.xlsx', index_col = '지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_values('키')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 6번    변덕규  능남고  202   80  100   95  85  80           C

# %%
df.sort_values('키')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 6번    변덕규  능남고  202   80  100   95  85  80           C

# %%
df.sort_values(['수학', '과학'])
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 1번    채치수  북산고  197   90   85  100  95  85      Python

# %%
df.sort_values(['과학','사회','SW특기'], ascending=False)
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 5번    강백호  북산고  188   15   20   10  35  10         NaN

# %%
df.sort_values('이름')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON

# %%
df.sort_values('SW특기', na_position='first')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 1번    채치수  북산고  197   90   85  100  95  85      Python

# %%
df.sort_values(['수학', '과학'], ascending = [True, False])
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 1번    채치수  북산고  197   90   85  100  95  85      Python

# %%
df.sort_values(['수학', '영어'], ascending=[True, False], kind = 'bubllesort') # 수학 점수는 오름차순, 영어 점수는 내림차순
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 1번    채치수  북산고  197   90   85  100  95  85      Python

# %%
df.sort_values?

# %%
df['키'].sort_values()
# Out:
# 지원번호
# 3번    168
# 2번    184
# 4번    187
# 5번    188
# 7번    188
# 8번    190
# 1번    197
# 6번    202
# Name: 키, dtype: int64

# %%
df.키.sort_values(ascending=False)
# Out:
# 지원번호
# 6번    202
# 1번    197
# 8번    190
# 5번    188
# 7번    188
# 4번    187
# 2번    184
# 3번    168
# Name: 키, dtype: int64

# %%
df.sort_index()
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_index?

# %%
df.sort_index(ignore_index=True, ascending = False)
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  윤대협  능남고  190  100   85   90  95  95          C#
# 1  황태산  능남고  188   55   65   45  40  35      PYTHON
# 2  변덕규  능남고  202   80  100   95  85  80           C
# 3  강백호  북산고  188   15   20   10  35  10         NaN
# 4  서태웅  북산고  187   40   60   70  75  80         NaN
# 5  송태섭  북산고  168   80   75   70  80  75  Javascript
# 6  정대만  북산고  184   40   35   50  55  25        Java
# 7  채치수  북산고  197   90   85  100  95  85      Python

# %%
df.sort_index()
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_index(ignore_index=True, ascending = False)
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  윤대협  능남고  190  100   85   90  95  95          C#
# 1  황태산  능남고  188   55   65   45  40  35      PYTHON
# 2  변덕규  능남고  202   80  100   95  85  80           C
# 3  강백호  북산고  188   15   20   10  35  10         NaN
# 4  서태웅  북산고  187   40   60   70  75  80         NaN
# 5  송태섭  북산고  168   80   75   70  80  75  Javascript
# 6  정대만  북산고  184   40   35   50  55  25        Java
# 7  채치수  북산고  197   90   85  100  95  85      Python
